# %%
import numpy as np
arr = np.array([1, 2, 3])
arr_2d = np.array([[1, 2, 3], [4, 5, 6]])

# %%
np.zeros((3, 3))
np.ones((2, 4))
np.eye(3)
np.arange(0, 10, 2)
np.linspace(0, 1, 5)
np.random.rand(3, 2)
np.random.randn(3, 2)
# Out:
# array([[-0.17074493,  1.39960028],
#        [-0.84067605, -0.23270084],
#        [-1.39217838,  0.4328006 ]])

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
print(arr.shape)
print(arr.ndim)
print(arr.size)
print(arr.dtype)
# Out:
# (2, 3)
# 2
# 6
# int64

# %%
a = np.array([1, 2, 3])

b = np.array([4, 5, 6])
a + b
a * b
np.sin(a)
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
np.dot(A, B)
A @ B
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
arr = np.array([1, 2, 3, 4])
arr.sum()
arr.mean()
arr.max()
arr.min()
arr.std()
# Out:
# np.float64(1.118033988749895)

# %%
arr = np.array([1, 2, 3, 4, 5])
arr[0]

arr[1:4]
arr[::2]
# Out:
# array([1, 3, 5])

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
arr[0, 1]
arr[:, 1]
arr[1, :2]
# Out:
# array([4, 5])

# %%
arr = np.array([1, 2, 3, 4, 5])
mask = arr > 3
arr[mask]
# Out:
# array([4, 5])

# %%
arr = np.arange(6)
arr.reshape(2, 3)
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
a = np.array([1, 2])
b = np.array([3, 4])
np.concatenate((a, b))
# Out:
# array([1, 2, 3, 4])

# %%
np.vstack((a, b))
np.hstack((a, b))
# Out:
# array([1, 2, 3, 4])

# %%
a = np.array([1, 2, 3])
a + 5 # [6, 7, 8]
# Out:
# array([6, 7, 8])

# %%
np.save('numpy.npy', arr)
